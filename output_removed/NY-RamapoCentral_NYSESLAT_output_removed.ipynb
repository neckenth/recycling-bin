# %%
#15-16
import pandas as pd
import numpy as np
import os
import re

from pyep import read_delimited
from pyep.settings import WORKSPACE_ROOT

df = read_delimited(r"C:\Workspace\ny-ramapocentral\NYSESLAT\Ramapo NYSESLAT 1516 Scores all - ELLevation.csv")

def helper(group):
    group.loc[:, 'Elv_GradeLevel'] = group.loc[:, 'Elv_GradeLevel'].max()
    return group

df['Test Name'].str.extract('(\w{8}:\s)(.-?\d{0,2}?\s)(\w{2,}\s?\w{5}?)')

df.loc[df['Test Name'].str.contains('Total Score'), 'Elv_GradeLevel'] = df['Test Name'].str.extract('\w{8}:\s(.-?\d{0,2}?\s)\w{2,}\s?\w{5}?')

df = df.groupby('Student ID').apply(helper)

df['Elv_Domain'] = df['Test Name'].str.extract('\w{8}:\s.-?\d{0,2}?\s(\w{2,}\s?\w{5}?)')

df=df.pivot_table(index=['Student ID', 'Testing Period Start Date', 'Elv_GradeLevel'],
                  columns='Elv_Domain',
                 values=['Performance Level', 'Score'],
                 aggfunc=np.max).reset_index(col_level=1)

df.columns=[' '.join(col).strip() for col in df.columns.tolist()]

df.head()

df.to_csv(r"C:\Workspace\ny-ramapocentral\NYSESLAT\NYSESLAT_processed.csv", index=False)

# %%
#14-15

import pandas as pd
import numpy as np
import os
import re

from pyep import read_delimited
from pyep.settings import WORKSPACE_ROOT

df = read_delimited(r"C:\Workspace\ny-ramapocentral\NYSESLAT\di-7423\NYSESLAT\1415 NYSESLAT scores Ramapo.csv", dtype=str)

def helper(group):
    group.loc[:, 'Elv_GradeLevel'] = group.loc[:, 'Elv_GradeLevel'].max()
    return group

df['Assessment Name'].str.extract('(\w{8}:\s)(.-?\d{0,2}\s)(\w{5,}\s?\w{0,5})')

df.loc[df['Assessment Name'].str.contains('Total Score'), 'Elv_GradeLevel'] = df['Assessment Name'].str.extract('\w{8}:\s(.-?\d{0,2}\s)\w{5,}\s?\w{0,5}')

#df['Elv_GradeLevel'].unique()

df = df.groupby('Student ID').apply(helper)

df['Elv_Domain'] = df['Assessment Name'].str.extract('\w{8}:\s.-?\d{0,2}\s(\w{5,}\s?\w{0,5})')

df['Elv_Domain'].unique()

df=df.pivot_table(index=['Student ID', 'Elv_GradeLevel'],
                  columns='Elv_Domain',
                 values=['Performance Level', 'Score'],
                 aggfunc=np.max).reset_index(col_level=1)

df.columns=[''.join(col).strip() for col in df.columns.tolist()]

df.head()

df.to_csv(r"C:\Workspace\ny-ramapocentral\NYSESLAT\di-7423\NYSESLAT\1415 NYSESLAT scores Ramapo_processed.csv", index=False)

# %%
#16-17

import pandas as pd
import numpy as np
import os
import re

from pyep import read_delimited
from pyep.settings import WORKSPACE_ROOT

df = read_delimited(r"C:\Workspace\ny-ramapocentral\elp-test-scores\Suffern 1617 NYSESLAT Scores.csv", dtype=str)

def helper(group):
    group.loc[:, 'Elv_GradeLevel'] = group.loc[:, 'Elv_GradeLevel'].max()
    return group

df['Assessment Name'].str.extract('(\w{8}:\s)(.-?\d{0,2}\s)(\w{5,}\s?\w{0,5})')

df.loc[df['Assessment Name'].str.contains('Total Score'), 'Elv_GradeLevel'] = df['Assessment Name'].str.extract('\w{8}:\s(.-?\d{0,2}\s)\w{5,}\s?\w{0,5}')

#df['Elv_GradeLevel'].unique()

df = df.groupby('Student ID').apply(helper)

print df.loc[:, 'Elv_GradeLevel'].unique()

df['Elv_Domain'] = df['Assessment Name'].str.extract('\w{8}:\s.-?\d{0,2}\s(\w{5,}\s?\w{0,5})')

print df['Elv_Domain'].unique()

df=df.pivot_table(index=['Student ID', 'Elv_GradeLevel', 'Testing Period Start Date'],
                  columns='Elv_Domain',
                 values=['Scale Score', 'Raw Score', 'Not Tested', 'Performance Level'],
                 aggfunc=np.max).reset_index(col_level=1)

df.columns=[''.join(col).strip() for col in df.columns.tolist()]

df = df[df.loc[:, 'Elv_GradeLevel'].notnull()]

df.to_csv(r"C:\Workspace\ny-ramapocentral\elp-test-scores\Suffern 1617 NYSESLAT Scores_processed.csv", index=False)
